# %% [markdown]
# # SimuBAQ – Data Cleaning Pipeline
#
# This notebook cleans and prepares the SimuBAQ survey dataset for BI analysis.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('simubaq_encuesta_1000_respuestas.csv')
df.head()
# Out:
#    id_encuestado fecha_respuesta edad_rango               genero  \
# 0              1      2025-11-24      40-49             Femenino
# 1              2      2025-11-25      60-69             Femenino
# 2              3      2025-11-23      60-69             Femenino
# 3              4      2025-11-28      60-69  Prefiero no decirlo
# 4              5      2025-11-18      40-49  Prefiero no decirlo
#
#          ciudad nivel_educativo    tipo_celular dispositivo_principal  \
# 0       Malambo    Bachillerato      Smartphone                Tablet
# 1        Galapa         Ninguno      Smartphone               Ninguno
# 2       Soledad        Primaria  Celular basico               Ninguno
# 3  Barranquilla        Primaria        No tiene            Computador
# 4       Soledad    Bachillerato        No tiene               Ninguno
#
#   acceso_internet  nivel_manejo_celular  ... horarios_disponibles  \
# 0        No tiene                     1  ...         Tarde, Noche
# 1            WiFi                     5  ...                Noche
# 2   Datos moviles                     1  ...        Manana, Noche
# 3        No tiene                     3  ...        Manana, Noche
# 4        No tiene                     2  ...                Noche
#
#   frecuencia_posible_semana duracion_preferida_clase tiempo_desplazamiento  \
# 0                   2 veces                   45 min                 21-40
# 1                   2 veces                   45 min                 11-20
# 2                     1 vez                   45 min                 11-20
# 3             3 veces o mas                   1 hora                 11-20
# 4                   2 veces                   45 min                  0-10
#
#   lugar_preferido_clases tipo_clase_preferida limitaciones   disposicion_pago  \
# 0                 Barrio           Individual      Memoria                 Si
# 1               Alcaldia          Indiferente   Motricidad  Solo si es gratis
# 2               Alcaldia           Individual      Memoria                 No
# 3                 Barrio        Grupo pequeno      Ninguna                 Si
# 4                 Barrio           Individual     Audicion                 Si
#
#      entidad_ideal contacto_interes
# 0  Empresa privada               No
# 1          Familia               Si
# 2          Familia               No
# 3         Alcaldia               No
# 4         Alcaldia               No
#
# [5 rows x 31 columns]

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_encuestado                1000 non-null   int64
#  1   fecha_respuesta              1000 non-null   object
#  2   edad_rango                   1000 non-null   object
#  3   genero                       1000 non-null   object
#  4   ciudad                       1000 non-null   object
#  5   nivel_educativo              1000 non-null   object
#  6   tipo_celular                 1000 non-null   object
#  7   dispositivo_principal        1000 non-null   object
#  8   acceso_internet              1000 non-null   object
#  9   nivel_manejo_celular         1000 non-null   int64
#  10  comodidad_apps               1000 non-null   object
#  11  frecuencia_uso_apps          1000 non-null   object
#  12  apps_usadas                  1000 non-null   object
#  13  uso_principal_celular        1000 non-null   object
#  14  dificultades                 1000 non-null   object
#  15  miedos                       1000 non-null   object
#  16  interes_clases_presenciales  1000 non-null   object
#  17  interes_simuladores          1000 non-null   object
#  18  apps_deseadas                1000 non-null   object
#  19  app_prioritaria              1000 non-null   object
#  20  dias_disponibles             1000 non-null   object
#  21  horarios_disponibles         1000 non-null   object
#  22  frecuencia_posible_semana    1000 non-null   object
#  23  duracion_preferida_clase     1000 non-null   object
#  24  tiempo_desplazamiento        1000 non-null   object
#  25  lugar_preferido_clases       1000 non-null   object
#  26  tipo_clase_preferida         1000 non-null   object
#  27  limitaciones                 1000 non-null   object
#  28  disposicion_pago             1000 non-null   object
#  29  entidad_ideal                1000 non-null   object
#  30  contacto_interes             1000 non-null   object
# dtypes: int64(2), object(29)
# memory usage: 242.3+ KB
# id_encuestado                  0
# fecha_respuesta                0
# edad_rango                     0
# genero                         0
# ciudad                         0
# nivel_educativo                0
# tipo_celular                   0
# dispositivo_principal          0
# acceso_internet                0
# nivel_manejo_celular           0
# comodidad_apps                 0
# frecuencia_uso_apps            0
# apps_usadas                    0
# uso_principal_celular          0
# dificultades                   0
# miedos                         0
# interes_clases_presenciales    0
# interes_simuladores            0
# apps_deseadas                  0
# app_prioritaria                0
# dias_disponibles               0
# horarios_disponibles           0
# frecuencia_posible_semana      0
# duracion_preferida_clase       0
# tiempo_desplazamiento          0
# lugar_preferido_clases         0
# tipo_clase_preferida           0
# limitaciones                   0
# disposicion_pago               0
# entidad_ideal                  0
# contacto_interes               0
# dtype: int64

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
      .str.replace("á", "a")
      .str.replace("é", "e")
      .str.replace("í", "i")
      .str.replace("ó", "o")
      .str.replace("ú", "u")
)
df.columns
# Out:
# Index(['id_encuestado', 'fecha_respuesta', 'edad_rango', 'genero', 'ciudad',
#        'nivel_educativo', 'tipo_celular', 'dispositivo_principal',
#        'acceso_internet', 'nivel_manejo_celular', 'comodidad_apps',
#        'frecuencia_uso_apps', 'apps_usadas', 'uso_principal_celular',
#        'dificultades', 'miedos', 'interes_clases_presenciales',
#        'interes_simuladores', 'apps_deseadas', 'app_prioritaria',
#        'dias_disponibles', 'horarios_disponibles', 'frecuencia_posible_semana',
#        'duracion_preferida_clase', 'tiempo_desplazamiento',
#        'lugar_preferido_clases', 'tipo_clase_preferida', 'limitaciones',
#        'disposicion_pago', 'entidad_ideal', 'contacto_interes'],
#       dtype='object')

# %%
text_columns = df.select_dtypes(include="object").columns
for col in text_columns:
    df[col] = (
        df[col]
        .astype(str)
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
        .str.title()
    )
df[text_columns].head()
# Out:
#   fecha_respuesta edad_rango               genero        ciudad  \
# 0      2025-11-24      40-49             Femenino       Malambo
# 1      2025-11-25      60-69             Femenino        Galapa
# 2      2025-11-23      60-69             Femenino       Soledad
# 3      2025-11-28      60-69  Prefiero No Decirlo  Barranquilla
# 4      2025-11-18      40-49  Prefiero No Decirlo       Soledad
#
#   nivel_educativo    tipo_celular dispositivo_principal acceso_internet  \
# 0    Bachillerato      Smartphone                Tablet        No Tiene
# 1         Ninguno      Smartphone               Ninguno            Wifi
# 2        Primaria  Celular Basico               Ninguno   Datos Moviles
# 3        Primaria        No Tiene            Computador        No Tiene
# 4    Bachillerato        No Tiene               Ninguno        No Tiene
#
#   comodidad_apps frecuencia_uso_apps  ... horarios_disponibles  \
# 0     Muy Comodo               Nunca  ...         Tarde, Noche
# 1        Neutral             A Veces  ...                Noche
# 2       Incomodo             A Veces  ...        Manana, Noche
# 3   Muy Incomodo             A Veces  ...        Manana, Noche
# 4        Neutral      Todos Los Dias  ...                Noche
#
#   frecuencia_posible_semana duracion_preferida_clase tiempo_desplazamiento  \
# 0                   2 Veces                   45 Min                 21-40
# 1                   2 Veces                   45 Min                 11-20
# 2                     1 Vez                   45 Min                 11-20
# 3             3 Veces O Mas                   1 Hora                 11-20
# 4                   2 Veces                   45 Min                  0-10
#
#   lugar_preferido_clases tipo_clase_preferida limitaciones   disposicion_pago  \
# 0                 Barrio           Individual      Memoria                 Si
# 1               Alcaldia          Indiferente   Motricidad  Solo Si Es Gratis
# 2               Alcaldia           Individual      Memoria                 No
# 3                 Barrio        Grupo Pequeno      Ninguna                 Si
# 4                 Barrio           Individual     Audicion                 Si
#
#      entidad_ideal contacto_interes
# 0  Empresa Privada               No
# 1          Familia               Si
# 2          Familia               No
# 3         Alcaldia               No
# 4         Alcaldia               No
#
# [5 rows x 29 columns]

# %%
multi_columns = [
    "apps_usadas","apps_deseadas","dias_disponibles",
    "horarios_disponibles","dificultades",
    "uso_principal_celular","limitaciones"
]
for col in multi_columns:
    df[col] = (
        df[col]
        .str.replace(" ,", ",")
        .str.replace(", ", ",")
        .str.replace(";", ",")
    )
df[multi_columns].head()
# Out:
#               apps_usadas            apps_deseadas         dias_disponibles  \
# 0   Correo,Whatsapp,Banca      Compras,Banca,Salud             Lunes,Martes
# 1  Youtube,Whatsapp,Banca     Redes Sociales,Banca         Martes,Miercoles
# 2                 Ninguna     Compras,Correo,Salud                   Martes
# 3          Youtube,Correo  Salud,Banca,Google Maps  Viernes,Lunes,Miercoles
# 4                   Banca                    Salud                Miercoles
#
#   horarios_disponibles                               dificultades  \
# 0          Tarde,Noche                                    Ninguna
# 1                Noche                      Miedo A Danar Celular
# 2         Manana,Noche                         Olvida Contrasenas
# 3         Manana,Noche              Ninguna,Miedo A Danar Celular
# 4                Noche  No Sabe Descargar Apps,Olvida Contrasenas
#
#   uso_principal_celular limitaciones
# 0              Mensajes      Memoria
# 1                Videos   Motricidad
# 2       Mapas,No Lo Usa      Memoria
# 3             No Lo Usa      Ninguna
# 4             No Lo Usa     Audicion

# %%
df["nivel_manejo_celular"] = pd.to_numeric(
    df["nivel_manejo_celular"], errors="coerce"
)
df = df[df["nivel_manejo_celular"].between(1, 5)]

# %%
df["fecha_respuesta"] = pd.to_datetime(
    df["fecha_respuesta"], errors="coerce"
)

# %%
df = df.drop_duplicates(subset=['id_encuestado'])

# %%
df.shape
df.isna().sum()
# Out:
# id_encuestado                  0
# fecha_respuesta                0
# edad_rango                     0
# genero                         0
# ciudad                         0
# nivel_educativo                0
# tipo_celular                   0
# dispositivo_principal          0
# acceso_internet                0
# nivel_manejo_celular           0
# comodidad_apps                 0
# frecuencia_uso_apps            0
# apps_usadas                    0
# uso_principal_celular          0
# dificultades                   0
# miedos                         0
# interes_clases_presenciales    0
# interes_simuladores            0
# apps_deseadas                  0
# app_prioritaria                0
# dias_disponibles               0
# horarios_disponibles           0
# frecuencia_posible_semana      0
# duracion_preferida_clase       0
# tiempo_desplazamiento          0
# lugar_preferido_clases         0
# tipo_clase_preferida           0
# limitaciones                   0
# disposicion_pago               0
# entidad_ideal                  0
# contacto_interes               0
# dtype: int64

# %%
df.to_csv(
    'simubaq_survey_clean.csv',
    index=False,
    encoding='utf-8'
)
print('Clean CSV exported')
# Out:
# Clean CSV exported

# %% [markdown]
# ## Dataset cleaned and ready for PostgreSQL and Power BI
